# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(2,9,10)
x
# Out:
# array([2.        , 2.77777778, 3.55555556, 4.33333333, 5.11111111,
#        5.88888889, 6.66666667, 7.44444444, 8.22222222, 9.        ])

# %%
y = x**2
y
# Out:
# array([ 4.        ,  7.71604938, 12.64197531, 18.77777778, 26.12345679,
#        34.67901235, 44.44444444, 55.41975309, 67.60493827, 81.        ])

# %%
plt.plot(x,y,'red')
plt.title("Este es mi gráfico")
plt.xlabel("Eje x")
plt.ylabel("Eje y")
plt.show()

# %%
plt.subplot(1,2,1)
plt.plot(x,y,'g') # La 'g' es porque se puede poner 'green' o 'g'

plt.subplot(1,2,2)
plt.plot(y,x,'blue')

# %%
plt.subplot(2,1,1)
plt.plot(x,y,'g') # La 'g' es porque se puede poner 'green' o 'g'

plt.subplot(2,1,2)
plt.plot(y,x,'blue')

# %% [markdown]
# Vamos a hacer lo mismo pero con la programación orientada a objetos

# %%
figura = plt.figure()
grafico = figura.add_axes([0.1,0.1,0.8,0.8])
grafico.plot(x,y,'green')

# %%
figura = plt.figure()
grafico1 = figura.add_axes([0.1,0.1,0.9,0.9])
grafico1.plot(x,y,'r')

grafico2 = figura.add_axes([0.15,0.5,0.3,0.3])
grafico2.plot(y,x,'blue')

# %% [markdown]
# ### Multigráficos (filas, columnas)

# %%
figura, graficos = plt.subplots(nrows=2, ncols=2)

graficos[0][0].plot(x,y,'blue')
graficos[0][1].plot(x,y,'red')
graficos[1][0].plot(x,y,'y')
graficos[1][1].plot(x,y,'g')

graficos[0][0].set_title('Azul')
graficos[0][1].set_title('Rojo')
graficos[1][0].set_title('Amarillo')
graficos[1][1].set_title('Verde')
# Out:
# Text(0.5, 1.0, 'Verde')

# %% [markdown]
# ### Tamaño del gráfico

# %%
figura = plt.figure(figsize=(10,2))
grafico = figura.add_axes([0.1,0.1,0.9,0.9])
grafico.plot(x,y,'r')

# %% [markdown]
# ### Dos gráficos en la misma figura

# %%
figura = plt.figure()
graficos = figura.add_axes([0.1,0.1,0.9,0.9])
graficos.plot(x, x**2, label='Al cuadrado')
graficos.plot(x, x**3, label='Al cubo')
graficos.legend(loc=0)

# %% [markdown]
# ### Color del gráfico

# %%
figura = plt.figure()
grafico = figura.add_axes([0, 0, 1, 1])
grafico.plot(x,y,'#872f1c')

# %% [markdown]
# ### Linea del gráfico (grosor, transparencia y tipo)

# %%
figura = plt.figure()
grafico = figura.add_axes([0,0,1,1])
grafico.plot(x,y,color='red',linewidth=10, alpha=0.5, linestyle='dotted')

# %% [markdown]
# ### Marcadores

# %%
x
# Out:
# array([2.        , 2.77777778, 3.55555556, 4.33333333, 5.11111111,
#        5.88888889, 6.66666667, 7.44444444, 8.22222222, 9.        ])

# %%
y
# Out:
# array([ 4.        ,  7.71604938, 12.64197531, 18.77777778, 26.12345679,
#        34.67901235, 44.44444444, 55.41975309, 67.60493827, 81.        ])

# %%
figura = plt.figure()
grafico = figura.add_axes([0,0,1,1])
grafico.plot(x,y,color='green', marker='o', markersize=5)
